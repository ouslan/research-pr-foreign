# %%
import os
os.chdir("..")

# %%
import duckdb
from src.submodule.jp_qcew.src.data.data_process import cleanData
import polars as pl

# %%
conn = duckdb.connect("data.ddb")

# %%
# conn.sql(
#     """
#     ALTER TABLE QCEWTable
#     RENAME TO USQCEWTable;;
# """)

# %%
conn.sql("SHOW TABLES;")
# Out:
# ┌─────────────┐
# │    name     │
# │   varchar   │
# ├─────────────┤
# │ CountyTable │
# │ DP03Table   │
# │ StateTable  │
# │ USQCEWTable │
# │ WageTable   │
# │ qcewtable   │
# └─────────────┘

# %%
conn.sql("DROP TABLE qcewtable;")

# %%
print(cleanData().make_qcew_dataset())
# Out:
# data/qcew/2002/022.EQUI.QTR.txt
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(cleanData().make_qcew_dataset())
#
# File ~/Documents/Github/research-pr-foreign/src/submodule/jp_qcew/src/data/data_process.py:61, in cleanData.make_qcew_dataset(self)
#      59 else:
#      60     for file in os.listdir(f"{self.saving_dir}qcew/{folder}"):
# ---> 61         df = self.clean_txt(
#      62             f"{self.saving_dir}qcew/{folder}/{file}",
#      63             f"{self.saving_dir}external/decode.json",
#      64         )
#      65         if df.is_empty():
#      66             logging.warning(f"File {file} is empty.")
#
# File ~/Documents/Github/research-pr-foreign/src/submodule/jp_qcew/src/data/data_process.py:96, in cleanData.clean_txt(self, dev_file, decode_path)
#      81 """
# ...

# %%
pl.read_csv(
            "data/qcew/2002/022.EQUI.QTR.txt",
            separator="\n",
            has_header=False,
            encoding="latin1",
            new_columns=["full_str"],
            ignore_errors=True
        )
# Out:
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pl.read_csv(
#       2             "data/qcew/2002/022.EQUI.QTR.txt",
#       3             separator="\n",
#       4             has_header=False,
#       5             encoding="latin1",
#       6             new_columns=["full_str"],
#       7         )
#
# File ~/Documents/Github/research-pr-foreign/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# ...
